# %%
# !pip install zss
# !pip install antlr4-python3-runtime==4.11
# Out:
# Collecting zss
#   Downloading zss-1.2.0.tar.gz (9.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from zss) (1.17.0)
# Building wheels for collected packages: zss
#   Building wheel for zss (setup.py) ... done
#   Created wheel for zss: filename=zss-1.2.0-py3-none-any.whl size=6725 sha256=3525038cfead24e2b8a60f0fac9b65d01f33fe7b1bd3453dad7be830a2268c30
#   Stored in directory: /root/.cache/pip/wheels/46/e7/2e/44fb39352ad468427a7528cacbefefaa438a898dfd1ad2eaa4
# Successfully built zss
# Installing collected packages: zss
# Successfully installed zss-1.2.0
# Collecting antlr4-python3-runtime==4.11
#   Downloading antlr4_python3_runtime-4.11.0-py3-none-any.whl.metadata (291 bytes)
# Downloading antlr4_python3_runtime-4.11.0-py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: antlr4-python3-runtime
#   Attempting uninstall: antlr4-python3-runtime
#     Found existing installation: antlr4-python3-runtime 4.9.3
#     Uninstalling antlr4-python3-runtime-4.9.3:
#       Successfully uninstalled antlr4-python3-runtime-4.9.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# omegaconf 2.3.0 requires antlr4-python3-runtime==4.9.*, but you have antlr4-python3-runtime 4.11.0 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.11.0

# %%
import os

repo_url = "https://github.com/smiling-demon/llm-symbolic-ode-reasoning.git"
repo_dir = "llm-symbolic-ode-reasoning"

if not os.path.exists(repo_dir):
    # !git clone {repo_url}

os.chdir(repo_dir)

# !pwd
# Out:
# Cloning into 'llm-symbolic-ode-reasoning'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 61 (delta 22), reused 49 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (61/61), 56.09 KiB | 2.67 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /kaggle/working/llm-symbolic-ode-reasoning

# %%
import pandas as pd

from llm import LLM
from methods import rsa
from metrics import evaluate_predictions

# %%
df = pd.read_excel("/kaggle/input/datasets/dmitrylessy/ode-basic-dataset/data/test.xlsx")

equations = df['equation'].tolist()
solutions = df['solution'].tolist()

# %%
llm = LLM("Qwen/Qwen2.5-3B-Instruct")
# Out:
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
# %%time

batch_size = 10
predictions = []

for i in range(0, len(equations), batch_size):
    predictions += rsa(llm, equations[i: i + batch_size], max_new_tokens=1024)
# Out:
# CPU times: user 49min 50s, sys: 1min 39s, total: 51min 30s
# Wall time: 51min 27s

# %%
evaluation = evaluate_predictions(predictions, solutions)
for key in evaluation:
    evaluation[key] = [evaluation[key]]
pd.DataFrame.from_dict(evaluation)
# Out:
#        bleu  ast_error_size  ast_tree_distance  exact_match
# 0  0.517876        1.883728           0.687487          0.3
